# %% [markdown]
# In this notebook, we generate finite element data for training neural operators.

# %% [markdown]
# ### General Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
from pathlib import Path

# %%
from mesher import Mesh2D
from conditions import BoundaryCondition
from materials import LinearElastic
from solver import NFEA

# %%
def get_periodic_pairs(mesh: 'Mesh2D', tol: float = 1e-8):
    """
    Generate periodic node pairs for a 2D mesh based on its geometry and node groups.
    """

    coords = mesh.coordinates  # shape (nnod, 2)

    # Get boundary nodes
    x_min, x_max = coords[:, 0].min(), coords[:, 0].max()
    y_min, y_max = coords[:, 1].min(), coords[:, 1].max()

    left_nodes   = mesh.find_nodes(x_min, axis=1, tol=tol)
    right_nodes  = mesh.find_nodes(x_max, axis=1, tol=tol)
    bottom_nodes = mesh.find_nodes(y_min, axis=2, tol=tol)
    top_nodes    = mesh.find_nodes(y_max, axis=2, tol=tol)

    # LEFT & RIGHT pairs (same Y-value)
    y_to_right = {round(coords[nid-1, 1], 8): nid for nid in right_nodes}

    left_right_pairs = []
    for nid_l in left_nodes:
        y_key = round(coords[nid_l-1, 1], 8)
        if y_key in y_to_right:
            left_right_pairs.append((nid_l, y_to_right[y_key]))

    # BOTTOM & TOP pairs (same X-value)
    x_to_top = {round(coords[nid-1, 0], 8): nid for nid in top_nodes}

    bottom_top_pairs = []
    for nid_b in bottom_nodes:
        x_key = round(coords[nid_b-1, 0], 8)
        if x_key in x_to_top:
            bottom_top_pairs.append((nid_b, x_to_top[x_key]))

    # Sort by coordinates
    left_right_pairs.sort(key=lambda p: coords[p[0]-1, 1])   # sort by Y
    bottom_top_pairs.sort(key=lambda p: coords[p[0]-1, 0])   # sort by X

    return left_right_pairs, bottom_top_pairs

# %%
from scipy.spatial import cKDTree

def get_periodic_pairs_kdtree(mesh, delta_x: float = None, delta_y: float = None, tol=1e-8):
    """
    Finds periodic node pairs (Left-Right, Bottom-Top) using KD-Tree for fast spatial querying.
    
    Args:
        mesh: Mesh2D object containing coordinates, dimensions (lx, ly), and node groups.
        tol (float): Spatial tolerance for matching nodes.
        
    Returns:
        tuple: Two lists of paired node IDs (1-based format) -> (pairs_left_right, pairs_bottom_top).
    """
    # Get all coordinates as a numpy array
    coords = np.array(mesh.coordinates)
    
    if delta_x is None:
        delta_x = max(coords[:, 0]) - min(coords[:, 0])
    if delta_y is None:
        delta_y = max(coords[:, 1]) - min(coords[:, 1])

    # Extract 0-based indices for boundary nodes (Mesh2D uses 1-based IDs)
    left_idx = np.array(list(mesh.node_groups['Xmin_n'])) - 1
    right_idx = np.array(list(mesh.node_groups['Xmax_n'])) - 1
    bottom_idx = np.array(list(mesh.node_groups['Ymin_n'])) - 1
    top_idx = np.array(list(mesh.node_groups['Ymax_n'])) - 1
    
    coords_left, coords_right = coords[left_idx], coords[right_idx]
    coords_bottom, coords_top = coords[bottom_idx], coords[top_idx]
    
    # ---------------------------------------------------------
    # LEFT-RIGHT PAIRING (X-axis)
    # ---------------------------------------------------------
    # Shift left boundary nodes by Lx to overlap the right boundary
    shifted_left = coords_left.copy()
    shifted_left[:, 0] += delta_x  
    
    # Build KD-Tree for right boundary and query matches
    tree_right = cKDTree(coords_right)
    distances_lr, indices_lr = tree_right.query(shifted_left, distance_upper_bound=tol)
    valid_lr = distances_lr < tol
    
    # Construct pairs and restore 1-based indexing
    left_nodes = (left_idx[valid_lr] + 1).tolist()
    right_nodes = (right_idx[indices_lr[valid_lr]] + 1).tolist()

    pairs_left_right = list(zip(left_nodes, right_nodes))
    
    # ---------------------------------------------------------
    # BOTTOM-TOP PAIRING (Y-axis)
    # ---------------------------------------------------------
    # Shift bottom boundary nodes by Ly to overlap the top boundary
    shifted_bottom = coords_bottom.copy()
    shifted_bottom[:, 1] += delta_y 
    
    # Build KD-Tree for top boundary and query matches
    tree_top = cKDTree(coords_top)
    distances_bt, indices_bt = tree_top.query(shifted_bottom, distance_upper_bound=tol)
    valid_bt = distances_bt < tol
    
    # Construct pairs and restore 1-based indexing
    bottom_nodes = (bottom_idx[valid_bt] + 1).tolist()
    top_nodes = (top_idx[indices_bt[valid_bt]] + 1).tolist()    
    
    pairs_bottom_top = list(zip(bottom_nodes, top_nodes))
    
    return pairs_left_right, pairs_bottom_top

# %%
from conditions import PeriodicBoundaryCondition
import torch
from utils import QuadShapeFunctions

# Material properties
E_soft = 10_000.0   # MPa
E_hard = 100_000.0  # MPa
nu_soft = 0.25
nu_hard = 0.25

soft = LinearElastic(emod =  E_soft, nu = nu_soft)
hard = LinearElastic(emod =  E_hard, nu = nu_hard)

# RVE dimensions
delta_x = 0.10      # RVE size in X direction in (mm)
delta_y = 0.10      # RVE size in Y direction in (mm)

# Configuration of input/output paths
meshes_folder = Path("./meshes")
strain_folder = Path("./strain_histories")

mesh_files  = sorted(meshes_folder.glob("*.med"))               # mesh 1, mesh 2, ...
strain_files = sorted(strain_folder.glob("strain_*.csv"))       # strain_1.csv, strain_2.csv, ...

output_dir = Path("./data/Run1")
output_dir.mkdir(parents=True, exist_ok=True)

# batch to solve
b_ini = 1           # inclusive
b_end = 1000        # inclusive

# Loop over batches
for idx in range(b_ini, b_end + 1):
    if idx < b_ini:
        continue
    if idx > b_end:
        break
    
    mesh_file = mesh_files[idx-1]
    strain_file = strain_files[idx-1]

    print(f"Processing {idx}/{b_end} → {mesh_file.name}")
    
    # Read mesh
    mesh = Mesh2D.from_salome_med(filepath=mesh_file, verbose=False)

    left_right_pairs, bottom_top_pairs = get_periodic_pairs_kdtree(mesh, delta_x=delta_x, delta_y=delta_y)

    # Define boundary conditions
    bcs = {
        'fixed_n': [BoundaryCondition(dof=1, value=0.0),
                    BoundaryCondition(dof=2, value=0.0)],  
        }
    
    # Define periodic boundary conditions
    strain_data = np.genfromtxt(
            strain_file,
            delimiter=',',
            names=True,
            dtype=float,
            skip_header=0
        )

    exx = strain_data['exx']
    eyy = strain_data['eyy']
    gxy = strain_data['gxy']
    n_steps = len(exx)
    
    pbc = PeriodicBoundaryCondition(
        exx=exx[0],
        eyy=eyy[0],
        gxy=gxy[0],
        left_right_pairs=left_right_pairs,
        bottom_top_pairs=bottom_top_pairs,
        delta_x=delta_x,
        delta_y=delta_y
        )

    mpcs = pbc.get_constraints()

    # Define material field mapping
    matfield = {'soft_s': soft, 
                'hard_s': hard}

    # Instance FEA solver
    fem_solver = NFEA(mesh = mesh, 
                      bcs = bcs,
                      matfld = matfield,
                      mpcs=mpcs,
                      verbose = False
                      )
    
    rve_file = output_dir / f"rve_{idx:04d}.h5"
    nchannels = 4   # phase_field (0=soft, 1=hard), sXX, sYY, sXY
    nmacro = 7      # exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard

    N_total = n_steps - 1 
    nelx = int(np.sqrt(fem_solver.nelem))
    nely = nelx                          
    ngp = 2
    H_gp = nely * ngp
    W_gp = nelx * ngp

    # Pre-calculate and store static GP data (coordinates + phase) for all groups
    gp_static_list = []
    for group_name, batch in fem_solver.quad_batches.items():
        emod_val = float(batch.material.emod)
        
        # Physical coordinates of Gauss points
        H_shape = QuadShapeFunctions(batch.r_gp, batch.s_gp, batch.nnode)
        X_gp = torch.einsum('gn,enj->egj', H_shape, batch.X)
        coords_flat = X_gp.reshape(-1, 2).cpu().numpy()
        
        # Phase (0.0 o 1.0)
        phase_val = 1.0 if emod_val == E_hard else 0.0
        phase_flat = np.full((len(coords_flat), 1), phase_val, dtype=np.float32)
        
        gp_static_list.append(np.hstack([coords_flat, phase_flat]))
    
    gp_static_array = np.vstack(gp_static_list)
    x_coords = np.round(gp_static_array[:, 0], decimals=5)
    y_coords = np.round(gp_static_array[:, 1], decimals=5)
    sort_idx = np.lexsort((x_coords, y_coords)) 
    
    phase_grid = gp_static_array[sort_idx, 2].reshape(H_gp, W_gp)

    with h5py.File(rve_file, 'w') as f:
        # Create datasets
        f.create_dataset('fields', 
                                 shape=(N_total, H_gp, W_gp, nchannels),
                                 dtype=np.float32, 
                                 compression='gzip', compression_opts=4)
        f.create_dataset('macro', 
                                 shape=(N_total, nmacro),
                                 dtype=np.float32, compression='gzip')
        # Save metadata
        f.attrs.update({
            'H_gp': H_gp, 
            'W_gp': W_gp, 
            'ngp': ngp, 
            'n_steps': N_total,
            'mesh_name': mesh_file.name,
            'description': 'Dual-Encoder FNO: '
                        'fields[phase(0=soft,1=hard), sXX, sYY, sXY] + '
                        'macro[exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard]'
        })

        # Loop over steps
        for step in range(1, n_steps):
            pbc.update_strains(new_exx=exx[step], new_eyy=eyy[step], new_gxy=gxy[step])
            fem_solver.update_mpc_b0s()
            fem_solver.run_complete(nsteps=1)

            # Compute stress at Gauss points for all groups
            sigma_list = []
            for group_name, batch in fem_solver.quad_batches.items():
                u_local = batch.get_local_disp(fem_solver.udisp)
                eps_gp = batch.compute_infinitesimal_strain(u_local)
                sigma_gp = batch.material.compute_stress(eps_gp)
                sigma_list.append(sigma_gp.reshape(-1, 3).cpu().numpy())

            sigma_flat = np.vstack(sigma_list)
            sigma_sorted = sigma_flat[sort_idx]

            # Reshape to structured grid
            data_step = np.zeros((H_gp, W_gp, nchannels), dtype=np.float32)
            data_step[..., 0] = phase_grid
            data_step[..., 1] = sigma_sorted[:, 0].reshape(H_gp, W_gp) # sXX
            data_step[..., 2] = sigma_sorted[:, 1].reshape(H_gp, W_gp) # sYY
            data_step[..., 3] = sigma_sorted[:, 2].reshape(H_gp, W_gp) # sXY

            # Global features
            macro_step = np.array([
                    exx[step], eyy[step], gxy[step],   # macro strain
                    E_soft, nu_soft,                   # soft phase
                    E_hard, nu_hard                    # hard phase
                ], dtype=np.float32)

            # Save
            f['fields'][step-1]     = data_step
            f['macro'][step-1]      = macro_step

print(f"\n Process finished. Files saved at:\n{output_dir}")
# Out:
# Processing 1/1000 → RVE_8x8_f0.40_0001.med
# Processing 2/1000 → RVE_8x8_f0.40_0002.med
# Processing 3/1000 → RVE_8x8_f0.40_0003.med
# Processing 4/1000 → RVE_8x8_f0.40_0004.med
# Processing 5/1000 → RVE_8x8_f0.40_0005.med
# Processing 6/1000 → RVE_8x8_f0.40_0006.med
# Processing 7/1000 → RVE_8x8_f0.40_0007.med
# Processing 8/1000 → RVE_8x8_f0.40_0008.med
# Processing 9/1000 → RVE_8x8_f0.40_0009.med
# Processing 10/1000 → RVE_8x8_f0.40_0010.med
# Processing 11/1000 → RVE_8x8_f0.40_0011.med
# Processing 12/1000 → RVE_8x8_f0.40_0012.med
# Processing 13/1000 → RVE_8x8_f0.40_0013.med
# Processing 14/1000 → RVE_8x8_f0.40_0014.med
# Processing 15/1000 → RVE_8x8_f0.40_0015.med
# Processing 16/1000 → RVE_8x8_f0.40_0016.med
# Processing 17/1000 → RVE_8x8_f0.40_0017.med
# Processing 18/1000 → RVE_8x8_f0.40_0018.med
# Processing 19/1000 → RVE_8x8_f0.40_0019.med
# Processing 20/1000 → RVE_8x8_f0.40_0020.med
# Processing 21/1000 → RVE_8x8_f0.40_0021.med
# Processing 22/1000 → RVE_8x8_f0.40_0022.med
# Processing 23/1000 → RVE_8x8_f0.40_0023.med
# Processing 24/1000 → RVE_8x8_f0.40_0024.med
# Processing 25/1000 → RVE_8x8_f0.40_0025.med
# Processing 26/1000 → RVE_8x8_f0.40_0026.med
# Processing 27/1000 → RVE_8x8_f0.40_0027.med
# Processing 28/1000 → RVE_8x8_f0.40_0028.med
# Processing 29/1000 → RVE_8x8_f0.40_0029.med
# Processing 30/1000 → RVE_8x8_f0.40_0030.med
# Processing 31/1000 → RVE_8x8_f0.40_0031.med
# Processing 32/1000 → RVE_8x8_f0.40_0032.med
# Processing 33/1000 → RVE_8x8_f0.40_0033.med
# Processing 34/1000 → RVE_8x8_f0.40_0034.med
# Processing 35/1000 → RVE_8x8_f0.40_0035.med
# Processing 36/1000 → RVE_8x8_f0.40_0036.med
# Processing 37/1000 → RVE_8x8_f0.40_0037.med
# Processing 38/1000 → RVE_8x8_f0.40_0038.med
# Processing 39/1000 → RVE_8x8_f0.40_0039.med
# Processing 40/1000 → RVE_8x8_f0.40_0040.med
# Processing 41/1000 → RVE_8x8_f0.40_0041.med
# Processing 42/1000 → RVE_8x8_f0.40_0042.med
# Processing 43/1000 → RVE_8x8_f0.40_0043.med
# Processing 44/1000 → RVE_8x8_f0.40_0044.med
# Processing 45/1000 → RVE_8x8_f0.40_0045.med
# Processing 46/1000 → RVE_8x8_f0.40_0046.med
# Processing 47/1000 → RVE_8x8_f0.40_0047.med
# Processing 48/1000 → RVE_8x8_f0.40_0048.med
# Processing 49/1000 → RVE_8x8_f0.40_0049.med
# Processing 50/1000 → RVE_8x8_f0.40_0050.med
# Processing 51/1000 → RVE_8x8_f0.40_0051.med
# Processing 52/1000 → RVE_8x8_f0.40_0052.med
# Processing 53/1000 → RVE_8x8_f0.40_0053.med
# Processing 54/1000 → RVE_8x8_f0.40_0054.med
# Processing 55/1000 → RVE_8x8_f0.40_0055.med
# Processing 56/1000 → RVE_8x8_f0.40_0056.med
# Processing 57/1000 → RVE_8x8_f0.40_0057.med
# Processing 58/1000 → RVE_8x8_f0.40_0058.med
# Processing 59/1000 → RVE_8x8_f0.40_0059.med
# Processing 60/1000 → RVE_8x8_f0.40_0060.med
# Processing 61/1000 → RVE_8x8_f0.40_0061.med
# Processing 62/1000 → RVE_8x8_f0.40_0062.med
# Processing 63/1000 → RVE_8x8_f0.40_0063.med
# Processing 64/1000 → RVE_8x8_f0.40_0064.med
# Processing 65/1000 → RVE_8x8_f0.40_0065.med
# Processing 66/1000 → RVE_8x8_f0.40_0066.med
# Processing 67/1000 → RVE_8x8_f0.40_0067.med
# Processing 68/1000 → RVE_8x8_f0.40_0068.med
# Processing 69/1000 → RVE_8x8_f0.40_0069.med
# Processing 70/1000 → RVE_8x8_f0.40_0070.med
# Processing 71/1000 → RVE_8x8_f0.40_0071.med
# Processing 72/1000 → RVE_8x8_f0.40_0072.med
# Processing 73/1000 → RVE_8x8_f0.40_0073.med
# Processing 74/1000 → RVE_8x8_f0.40_0074.med
# Processing 75/1000 → RVE_8x8_f0.40_0075.med
# Processing 76/1000 → RVE_8x8_f0.40_0076.med
# Processing 77/1000 → RVE_8x8_f0.40_0077.med
# Processing 78/1000 → RVE_8x8_f0.40_0078.med
# Processing 79/1000 → RVE_8x8_f0.40_0079.med
# Processing 80/1000 → RVE_8x8_f0.40_0080.med
# Processing 81/1000 → RVE_8x8_f0.40_0081.med
# Processing 82/1000 → RVE_8x8_f0.40_0082.med
# Processing 83/1000 → RVE_8x8_f0.40_0083.med
# Processing 84/1000 → RVE_8x8_f0.40_0084.med
# Processing 85/1000 → RVE_8x8_f0.40_0085.med
# Processing 86/1000 → RVE_8x8_f0.40_0086.med
# Processing 87/1000 → RVE_8x8_f0.40_0087.med
# Processing 88/1000 → RVE_8x8_f0.40_0088.med
# Processing 89/1000 → RVE_8x8_f0.40_0089.med
# Processing 90/1000 → RVE_8x8_f0.40_0090.med
# Processing 91/1000 → RVE_8x8_f0.40_0091.med
# Processing 92/1000 → RVE_8x8_f0.40_0092.med
# Processing 93/1000 → RVE_8x8_f0.40_0093.med
# Processing 94/1000 → RVE_8x8_f0.40_0094.med
# Processing 95/1000 → RVE_8x8_f0.40_0095.med
# Processing 96/1000 → RVE_8x8_f0.40_0096.med
# Processing 97/1000 → RVE_8x8_f0.40_0097.med
# Processing 98/1000 → RVE_8x8_f0.40_0098.med
# Processing 99/1000 → RVE_8x8_f0.40_0099.med
# Processing 100/1000 → RVE_8x8_f0.40_0100.med
# Processing 101/1000 → RVE_8x8_f0.40_0101.med
# Processing 102/1000 → RVE_8x8_f0.40_0102.med
# Processing 103/1000 → RVE_8x8_f0.40_0103.med
# Processing 104/1000 → RVE_8x8_f0.40_0104.med
# Processing 105/1000 → RVE_8x8_f0.40_0105.med
# Processing 106/1000 → RVE_8x8_f0.40_0106.med
# Processing 107/1000 → RVE_8x8_f0.40_0107.med
# Processing 108/1000 → RVE_8x8_f0.40_0108.med
# Processing 109/1000 → RVE_8x8_f0.40_0109.med
# Processing 110/1000 → RVE_8x8_f0.40_0110.med
# Processing 111/1000 → RVE_8x8_f0.40_0111.med
# Processing 112/1000 → RVE_8x8_f0.40_0112.med
# Processing 113/1000 → RVE_8x8_f0.40_0113.med
# Processing 114/1000 → RVE_8x8_f0.40_0114.med
# Processing 115/1000 → RVE_8x8_f0.40_0115.med
# Processing 116/1000 → RVE_8x8_f0.40_0116.med
# Processing 117/1000 → RVE_8x8_f0.40_0117.med
# Processing 118/1000 → RVE_8x8_f0.40_0118.med
# Processing 119/1000 → RVE_8x8_f0.40_0119.med
# Processing 120/1000 → RVE_8x8_f0.40_0120.med
# Processing 121/1000 → RVE_8x8_f0.40_0121.med
# Processing 122/1000 → RVE_8x8_f0.40_0122.med
# Processing 123/1000 → RVE_8x8_f0.40_0123.med
# Processing 124/1000 → RVE_8x8_f0.40_0124.med
# Processing 125/1000 → RVE_8x8_f0.40_0125.med
# Processing 126/1000 → RVE_8x8_f0.40_0126.med
# Processing 127/1000 → RVE_8x8_f0.40_0127.med
# Processing 128/1000 → RVE_8x8_f0.40_0128.med
# Processing 129/1000 → RVE_8x8_f0.40_0129.med
# Processing 130/1000 → RVE_8x8_f0.40_0130.med
# Processing 131/1000 → RVE_8x8_f0.40_0131.med
# Processing 132/1000 → RVE_8x8_f0.40_0132.med
# Processing 133/1000 → RVE_8x8_f0.40_0133.med
# Processing 134/1000 → RVE_8x8_f0.40_0134.med
# Processing 135/1000 → RVE_8x8_f0.40_0135.med
# Processing 136/1000 → RVE_8x8_f0.40_0136.med
# Processing 137/1000 → RVE_8x8_f0.40_0137.med
# Processing 138/1000 → RVE_8x8_f0.40_0138.med
# Processing 139/1000 → RVE_8x8_f0.40_0139.med
# Processing 140/1000 → RVE_8x8_f0.40_0140.med
# Processing 141/1000 → RVE_8x8_f0.40_0141.med
# Processing 142/1000 → RVE_8x8_f0.40_0142.med
# Processing 143/1000 → RVE_8x8_f0.40_0143.med
# Processing 144/1000 → RVE_8x8_f0.40_0144.med
# Processing 145/1000 → RVE_8x8_f0.40_0145.med
# Processing 146/1000 → RVE_8x8_f0.40_0146.med
# Processing 147/1000 → RVE_8x8_f0.40_0147.med
# Processing 148/1000 → RVE_8x8_f0.40_0148.med
# Processing 149/1000 → RVE_8x8_f0.40_0149.med
# Processing 150/1000 → RVE_8x8_f0.40_0150.med
# Processing 151/1000 → RVE_8x8_f0.40_0151.med
# Processing 152/1000 → RVE_8x8_f0.40_0152.med
# Processing 153/1000 → RVE_8x8_f0.40_0153.med
# Processing 154/1000 → RVE_8x8_f0.40_0154.med
# Processing 155/1000 → RVE_8x8_f0.40_0155.med
# Processing 156/1000 → RVE_8x8_f0.40_0156.med
# Processing 157/1000 → RVE_8x8_f0.40_0157.med
# Processing 158/1000 → RVE_8x8_f0.40_0158.med
# Processing 159/1000 → RVE_8x8_f0.40_0159.med
# Processing 160/1000 → RVE_8x8_f0.40_0160.med
# Processing 161/1000 → RVE_8x8_f0.40_0161.med
# Processing 162/1000 → RVE_8x8_f0.40_0162.med
# Processing 163/1000 → RVE_8x8_f0.40_0163.med
# Processing 164/1000 → RVE_8x8_f0.40_0164.med
# Processing 165/1000 → RVE_8x8_f0.40_0165.med
# Processing 166/1000 → RVE_8x8_f0.40_0166.med
# Processing 167/1000 → RVE_8x8_f0.40_0167.med
# Processing 168/1000 → RVE_8x8_f0.40_0168.med
# Processing 169/1000 → RVE_8x8_f0.40_0169.med
# Processing 170/1000 → RVE_8x8_f0.40_0170.med
# Processing 171/1000 → RVE_8x8_f0.40_0171.med
# Processing 172/1000 → RVE_8x8_f0.40_0172.med
# Processing 173/1000 → RVE_8x8_f0.40_0173.med
# Processing 174/1000 → RVE_8x8_f0.40_0174.med
# Processing 175/1000 → RVE_8x8_f0.40_0175.med
# Processing 176/1000 → RVE_8x8_f0.40_0176.med
# Processing 177/1000 → RVE_8x8_f0.40_0177.med
# Processing 178/1000 → RVE_8x8_f0.40_0178.med
# Processing 179/1000 → RVE_8x8_f0.40_0179.med
# Processing 180/1000 → RVE_8x8_f0.40_0180.med
# Processing 181/1000 → RVE_8x8_f0.40_0181.med
# Processing 182/1000 → RVE_8x8_f0.40_0182.med
# Processing 183/1000 → RVE_8x8_f0.40_0183.med
# Processing 184/1000 → RVE_8x8_f0.40_0184.med
# Processing 185/1000 → RVE_8x8_f0.40_0185.med
# Processing 186/1000 → RVE_8x8_f0.40_0186.med
# Processing 187/1000 → RVE_8x8_f0.40_0187.med
# Processing 188/1000 → RVE_8x8_f0.40_0188.med
# Processing 189/1000 → RVE_8x8_f0.40_0189.med
# Processing 190/1000 → RVE_8x8_f0.40_0190.med
# Processing 191/1000 → RVE_8x8_f0.40_0191.med
# Processing 192/1000 → RVE_8x8_f0.40_0192.med
# Processing 193/1000 → RVE_8x8_f0.40_0193.med
# Processing 194/1000 → RVE_8x8_f0.40_0194.med
# Processing 195/1000 → RVE_8x8_f0.40_0195.med
# Processing 196/1000 → RVE_8x8_f0.40_0196.med
# Processing 197/1000 → RVE_8x8_f0.40_0197.med
# Processing 198/1000 → RVE_8x8_f0.40_0198.med
# Processing 199/1000 → RVE_8x8_f0.40_0199.med
# Processing 200/1000 → RVE_8x8_f0.40_0200.med
# Processing 201/1000 → RVE_8x8_f0.40_0201.med
# Processing 202/1000 → RVE_8x8_f0.40_0202.med
# Processing 203/1000 → RVE_8x8_f0.40_0203.med
# Processing 204/1000 → RVE_8x8_f0.40_0204.med
# Processing 205/1000 → RVE_8x8_f0.40_0205.med
# Processing 206/1000 → RVE_8x8_f0.40_0206.med
# Processing 207/1000 → RVE_8x8_f0.40_0207.med
# Processing 208/1000 → RVE_8x8_f0.40_0208.med
# Processing 209/1000 → RVE_8x8_f0.40_0209.med
# Processing 210/1000 → RVE_8x8_f0.40_0210.med
# Processing 211/1000 → RVE_8x8_f0.40_0211.med
# Processing 212/1000 → RVE_8x8_f0.40_0212.med
# Processing 213/1000 → RVE_8x8_f0.40_0213.med
# Processing 214/1000 → RVE_8x8_f0.40_0214.med
# Processing 215/1000 → RVE_8x8_f0.40_0215.med
# Processing 216/1000 → RVE_8x8_f0.40_0216.med
# Processing 217/1000 → RVE_8x8_f0.40_0217.med
# Processing 218/1000 → RVE_8x8_f0.40_0218.med
# Processing 219/1000 → RVE_8x8_f0.40_0219.med
# Processing 220/1000 → RVE_8x8_f0.40_0220.med
# Processing 221/1000 → RVE_8x8_f0.40_0221.med
# Processing 222/1000 → RVE_8x8_f0.40_0222.med
# Processing 223/1000 → RVE_8x8_f0.40_0223.med
# Processing 224/1000 → RVE_8x8_f0.40_0224.med
# Processing 225/1000 → RVE_8x8_f0.40_0225.med
# Processing 226/1000 → RVE_8x8_f0.40_0226.med
# Processing 227/1000 → RVE_8x8_f0.40_0227.med
# Processing 228/1000 → RVE_8x8_f0.40_0228.med
# Processing 229/1000 → RVE_8x8_f0.40_0229.med
# Processing 230/1000 → RVE_8x8_f0.40_0230.med
# Processing 231/1000 → RVE_8x8_f0.40_0231.med
# Processing 232/1000 → RVE_8x8_f0.40_0232.med
# Processing 233/1000 → RVE_8x8_f0.40_0233.med
# Processing 234/1000 → RVE_8x8_f0.40_0234.med
# Processing 235/1000 → RVE_8x8_f0.40_0235.med
# Processing 236/1000 → RVE_8x8_f0.40_0236.med
# Processing 237/1000 → RVE_8x8_f0.40_0237.med
# Processing 238/1000 → RVE_8x8_f0.40_0238.med
# Processing 239/1000 → RVE_8x8_f0.40_0239.med
# Processing 240/1000 → RVE_8x8_f0.40_0240.med
# Processing 241/1000 → RVE_8x8_f0.40_0241.med
# Processing 242/1000 → RVE_8x8_f0.40_0242.med
# Processing 243/1000 → RVE_8x8_f0.40_0243.med
# Processing 244/1000 → RVE_8x8_f0.40_0244.med
# Processing 245/1000 → RVE_8x8_f0.40_0245.med
# Processing 246/1000 → RVE_8x8_f0.40_0246.med
# Processing 247/1000 → RVE_8x8_f0.40_0247.med
# Processing 248/1000 → RVE_8x8_f0.40_0248.med
# Processing 249/1000 → RVE_8x8_f0.40_0249.med
# Processing 250/1000 → RVE_8x8_f0.40_0250.med
# Processing 251/1000 → RVE_8x8_f0.40_0251.med
# Processing 252/1000 → RVE_8x8_f0.40_0252.med
# Processing 253/1000 → RVE_8x8_f0.40_0253.med
# Processing 254/1000 → RVE_8x8_f0.40_0254.med
# Processing 255/1000 → RVE_8x8_f0.40_0255.med
# Processing 256/1000 → RVE_8x8_f0.40_0256.med
# Processing 257/1000 → RVE_8x8_f0.40_0257.med
# Processing 258/1000 → RVE_8x8_f0.40_0258.med
# Processing 259/1000 → RVE_8x8_f0.40_0259.med
# Processing 260/1000 → RVE_8x8_f0.40_0260.med
# Processing 261/1000 → RVE_8x8_f0.40_0261.med
# Processing 262/1000 → RVE_8x8_f0.40_0262.med
# Processing 263/1000 → RVE_8x8_f0.40_0263.med
# Processing 264/1000 → RVE_8x8_f0.40_0264.med
# Processing 265/1000 → RVE_8x8_f0.40_0265.med
# Processing 266/1000 → RVE_8x8_f0.40_0266.med
# Processing 267/1000 → RVE_8x8_f0.40_0267.med
# Processing 268/1000 → RVE_8x8_f0.40_0268.med
# Processing 269/1000 → RVE_8x8_f0.40_0269.med
# Processing 270/1000 → RVE_8x8_f0.40_0270.med
# Processing 271/1000 → RVE_8x8_f0.40_0271.med
# Processing 272/1000 → RVE_8x8_f0.40_0272.med
# Processing 273/1000 → RVE_8x8_f0.40_0273.med
# Processing 274/1000 → RVE_8x8_f0.40_0274.med
# Processing 275/1000 → RVE_8x8_f0.40_0275.med
# Processing 276/1000 → RVE_8x8_f0.40_0276.med
# Processing 277/1000 → RVE_8x8_f0.40_0277.med
# Processing 278/1000 → RVE_8x8_f0.40_0278.med
# Processing 279/1000 → RVE_8x8_f0.40_0279.med
# Processing 280/1000 → RVE_8x8_f0.40_0280.med
# Processing 281/1000 → RVE_8x8_f0.40_0281.med
# Processing 282/1000 → RVE_8x8_f0.40_0282.med
# Processing 283/1000 → RVE_8x8_f0.40_0283.med
# Processing 284/1000 → RVE_8x8_f0.40_0284.med
# Processing 285/1000 → RVE_8x8_f0.40_0285.med
# Processing 286/1000 → RVE_8x8_f0.40_0286.med
# Processing 287/1000 → RVE_8x8_f0.40_0287.med
# Processing 288/1000 → RVE_8x8_f0.40_0288.med
# Processing 289/1000 → RVE_8x8_f0.40_0289.med
# Processing 290/1000 → RVE_8x8_f0.40_0290.med
# Processing 291/1000 → RVE_8x8_f0.40_0291.med
# Processing 292/1000 → RVE_8x8_f0.40_0292.med
# Processing 293/1000 → RVE_8x8_f0.40_0293.med
# Processing 294/1000 → RVE_8x8_f0.40_0294.med
# Processing 295/1000 → RVE_8x8_f0.40_0295.med
# Processing 296/1000 → RVE_8x8_f0.40_0296.med
# Processing 297/1000 → RVE_8x8_f0.40_0297.med
# Processing 298/1000 → RVE_8x8_f0.40_0298.med
# Processing 299/1000 → RVE_8x8_f0.40_0299.med
# Processing 300/1000 → RVE_8x8_f0.40_0300.med
# Processing 301/1000 → RVE_8x8_f0.40_0301.med
# Processing 302/1000 → RVE_8x8_f0.40_0302.med
# Processing 303/1000 → RVE_8x8_f0.40_0303.med
# Processing 304/1000 → RVE_8x8_f0.40_0304.med
# Processing 305/1000 → RVE_8x8_f0.40_0305.med
# Processing 306/1000 → RVE_8x8_f0.40_0306.med
# Processing 307/1000 → RVE_8x8_f0.40_0307.med
# Processing 308/1000 → RVE_8x8_f0.40_0308.med
# Processing 309/1000 → RVE_8x8_f0.40_0309.med
# Processing 310/1000 → RVE_8x8_f0.40_0310.med
# Processing 311/1000 → RVE_8x8_f0.40_0311.med
# Processing 312/1000 → RVE_8x8_f0.40_0312.med
# Processing 313/1000 → RVE_8x8_f0.40_0313.med
# Processing 314/1000 → RVE_8x8_f0.40_0314.med
# Processing 315/1000 → RVE_8x8_f0.40_0315.med
# Processing 316/1000 → RVE_8x8_f0.40_0316.med
# Processing 317/1000 → RVE_8x8_f0.40_0317.med
# Processing 318/1000 → RVE_8x8_f0.40_0318.med
# Processing 319/1000 → RVE_8x8_f0.40_0319.med
# Processing 320/1000 → RVE_8x8_f0.40_0320.med
# Processing 321/1000 → RVE_8x8_f0.40_0321.med
# Processing 322/1000 → RVE_8x8_f0.40_0322.med
# Processing 323/1000 → RVE_8x8_f0.40_0323.med
# Processing 324/1000 → RVE_8x8_f0.40_0324.med
# Processing 325/1000 → RVE_8x8_f0.40_0325.med
# Processing 326/1000 → RVE_8x8_f0.40_0326.med
# Processing 327/1000 → RVE_8x8_f0.40_0327.med
# Processing 328/1000 → RVE_8x8_f0.40_0328.med
# Processing 329/1000 → RVE_8x8_f0.40_0329.med
# Processing 330/1000 → RVE_8x8_f0.40_0330.med
# Processing 331/1000 → RVE_8x8_f0.40_0331.med
# Processing 332/1000 → RVE_8x8_f0.40_0332.med
# Processing 333/1000 → RVE_8x8_f0.40_0333.med
# Processing 334/1000 → RVE_8x8_f0.40_0334.med
# Processing 335/1000 → RVE_8x8_f0.40_0335.med
# Processing 336/1000 → RVE_8x8_f0.40_0336.med
# Processing 337/1000 → RVE_8x8_f0.40_0337.med
# Processing 338/1000 → RVE_8x8_f0.40_0338.med
# Processing 339/1000 → RVE_8x8_f0.40_0339.med
# Processing 340/1000 → RVE_8x8_f0.40_0340.med
# Processing 341/1000 → RVE_8x8_f0.40_0341.med
# Processing 342/1000 → RVE_8x8_f0.40_0342.med
# Processing 343/1000 → RVE_8x8_f0.40_0343.med
# Processing 344/1000 → RVE_8x8_f0.40_0344.med
# Processing 345/1000 → RVE_8x8_f0.40_0345.med
# Processing 346/1000 → RVE_8x8_f0.40_0346.med
# Processing 347/1000 → RVE_8x8_f0.40_0347.med
# Processing 348/1000 → RVE_8x8_f0.40_0348.med
# Processing 349/1000 → RVE_8x8_f0.40_0349.med
# Processing 350/1000 → RVE_8x8_f0.40_0350.med
# Processing 351/1000 → RVE_8x8_f0.40_0351.med
# Processing 352/1000 → RVE_8x8_f0.40_0352.med
# Processing 353/1000 → RVE_8x8_f0.40_0353.med
# Processing 354/1000 → RVE_8x8_f0.40_0354.med
# Processing 355/1000 → RVE_8x8_f0.40_0355.med
# Processing 356/1000 → RVE_8x8_f0.40_0356.med
# Processing 357/1000 → RVE_8x8_f0.40_0357.med
# Processing 358/1000 → RVE_8x8_f0.40_0358.med
# Processing 359/1000 → RVE_8x8_f0.40_0359.med
# Processing 360/1000 → RVE_8x8_f0.40_0360.med
# Processing 361/1000 → RVE_8x8_f0.40_0361.med
# Processing 362/1000 → RVE_8x8_f0.40_0362.med
# Processing 363/1000 → RVE_8x8_f0.40_0363.med
# Processing 364/1000 → RVE_8x8_f0.40_0364.med
# Processing 365/1000 → RVE_8x8_f0.40_0365.med
# Processing 366/1000 → RVE_8x8_f0.40_0366.med
# Processing 367/1000 → RVE_8x8_f0.40_0367.med
# Processing 368/1000 → RVE_8x8_f0.40_0368.med
# Processing 369/1000 → RVE_8x8_f0.40_0369.med
# Processing 370/1000 → RVE_8x8_f0.40_0370.med
# Processing 371/1000 → RVE_8x8_f0.40_0371.med
# Processing 372/1000 → RVE_8x8_f0.40_0372.med
# Processing 373/1000 → RVE_8x8_f0.40_0373.med
# Processing 374/1000 → RVE_8x8_f0.40_0374.med
# Processing 375/1000 → RVE_8x8_f0.40_0375.med
# Processing 376/1000 → RVE_8x8_f0.40_0376.med
# Processing 377/1000 → RVE_8x8_f0.40_0377.med
# Processing 378/1000 → RVE_8x8_f0.40_0378.med
# Processing 379/1000 → RVE_8x8_f0.40_0379.med
# Processing 380/1000 → RVE_8x8_f0.40_0380.med
# Processing 381/1000 → RVE_8x8_f0.40_0381.med
# Processing 382/1000 → RVE_8x8_f0.40_0382.med
# Processing 383/1000 → RVE_8x8_f0.40_0383.med
# Processing 384/1000 → RVE_8x8_f0.40_0384.med
# Processing 385/1000 → RVE_8x8_f0.40_0385.med
# Processing 386/1000 → RVE_8x8_f0.40_0386.med
# Processing 387/1000 → RVE_8x8_f0.40_0387.med
# Processing 388/1000 → RVE_8x8_f0.40_0388.med
# Processing 389/1000 → RVE_8x8_f0.40_0389.med
# Processing 390/1000 → RVE_8x8_f0.40_0390.med
# Processing 391/1000 → RVE_8x8_f0.40_0391.med
# Processing 392/1000 → RVE_8x8_f0.40_0392.med
# Processing 393/1000 → RVE_8x8_f0.40_0393.med
# Processing 394/1000 → RVE_8x8_f0.40_0394.med
# Processing 395/1000 → RVE_8x8_f0.40_0395.med
# Processing 396/1000 → RVE_8x8_f0.40_0396.med
# Processing 397/1000 → RVE_8x8_f0.40_0397.med
# Processing 398/1000 → RVE_8x8_f0.40_0398.med
# Processing 399/1000 → RVE_8x8_f0.40_0399.med
# Processing 400/1000 → RVE_8x8_f0.40_0400.med
# Processing 401/1000 → RVE_8x8_f0.40_0401.med
# Processing 402/1000 → RVE_8x8_f0.40_0402.med
# Processing 403/1000 → RVE_8x8_f0.40_0403.med
# Processing 404/1000 → RVE_8x8_f0.40_0404.med
# Processing 405/1000 → RVE_8x8_f0.40_0405.med
# Processing 406/1000 → RVE_8x8_f0.40_0406.med
# Processing 407/1000 → RVE_8x8_f0.40_0407.med
# Processing 408/1000 → RVE_8x8_f0.40_0408.med
# Processing 409/1000 → RVE_8x8_f0.40_0409.med
# Processing 410/1000 → RVE_8x8_f0.40_0410.med
# Processing 411/1000 → RVE_8x8_f0.40_0411.med
# Processing 412/1000 → RVE_8x8_f0.40_0412.med
# Processing 413/1000 → RVE_8x8_f0.40_0413.med
# Processing 414/1000 → RVE_8x8_f0.40_0414.med
# Processing 415/1000 → RVE_8x8_f0.40_0415.med
# Processing 416/1000 → RVE_8x8_f0.40_0416.med
# Processing 417/1000 → RVE_8x8_f0.40_0417.med
# Processing 418/1000 → RVE_8x8_f0.40_0418.med
# Processing 419/1000 → RVE_8x8_f0.40_0419.med
# Processing 420/1000 → RVE_8x8_f0.40_0420.med
# Processing 421/1000 → RVE_8x8_f0.40_0421.med
# Processing 422/1000 → RVE_8x8_f0.40_0422.med
# Processing 423/1000 → RVE_8x8_f0.40_0423.med
# Processing 424/1000 → RVE_8x8_f0.40_0424.med
# Processing 425/1000 → RVE_8x8_f0.40_0425.med
# Processing 426/1000 → RVE_8x8_f0.40_0426.med
# Processing 427/1000 → RVE_8x8_f0.40_0427.med
# Processing 428/1000 → RVE_8x8_f0.40_0428.med
# Processing 429/1000 → RVE_8x8_f0.40_0429.med
# Processing 430/1000 → RVE_8x8_f0.40_0430.med
# Processing 431/1000 → RVE_8x8_f0.40_0431.med
# Processing 432/1000 → RVE_8x8_f0.40_0432.med
# Processing 433/1000 → RVE_8x8_f0.40_0433.med
# Processing 434/1000 → RVE_8x8_f0.40_0434.med
# Processing 435/1000 → RVE_8x8_f0.40_0435.med
# Processing 436/1000 → RVE_8x8_f0.40_0436.med
# Processing 437/1000 → RVE_8x8_f0.40_0437.med
# Processing 438/1000 → RVE_8x8_f0.40_0438.med
# Processing 439/1000 → RVE_8x8_f0.40_0439.med
# Processing 440/1000 → RVE_8x8_f0.40_0440.med
# Processing 441/1000 → RVE_8x8_f0.40_0441.med
# Processing 442/1000 → RVE_8x8_f0.40_0442.med
# Processing 443/1000 → RVE_8x8_f0.40_0443.med
# Processing 444/1000 → RVE_8x8_f0.40_0444.med
# Processing 445/1000 → RVE_8x8_f0.40_0445.med
# Processing 446/1000 → RVE_8x8_f0.40_0446.med
# Processing 447/1000 → RVE_8x8_f0.40_0447.med
# Processing 448/1000 → RVE_8x8_f0.40_0448.med
# Processing 449/1000 → RVE_8x8_f0.40_0449.med
# Processing 450/1000 → RVE_8x8_f0.40_0450.med
# Processing 451/1000 → RVE_8x8_f0.40_0451.med
# Processing 452/1000 → RVE_8x8_f0.40_0452.med
# Processing 453/1000 → RVE_8x8_f0.40_0453.med
# Processing 454/1000 → RVE_8x8_f0.40_0454.med
# Processing 455/1000 → RVE_8x8_f0.40_0455.med
# Processing 456/1000 → RVE_8x8_f0.40_0456.med
# Processing 457/1000 → RVE_8x8_f0.40_0457.med
# Processing 458/1000 → RVE_8x8_f0.40_0458.med
# Processing 459/1000 → RVE_8x8_f0.40_0459.med
# Processing 460/1000 → RVE_8x8_f0.40_0460.med
# Processing 461/1000 → RVE_8x8_f0.40_0461.med
# Processing 462/1000 → RVE_8x8_f0.40_0462.med
# Processing 463/1000 → RVE_8x8_f0.40_0463.med
# Processing 464/1000 → RVE_8x8_f0.40_0464.med
# Processing 465/1000 → RVE_8x8_f0.40_0465.med
# Processing 466/1000 → RVE_8x8_f0.40_0466.med
# Processing 467/1000 → RVE_8x8_f0.40_0467.med
# Processing 468/1000 → RVE_8x8_f0.40_0468.med
# Processing 469/1000 → RVE_8x8_f0.40_0469.med
# Processing 470/1000 → RVE_8x8_f0.40_0470.med
# Processing 471/1000 → RVE_8x8_f0.40_0471.med
# Processing 472/1000 → RVE_8x8_f0.40_0472.med
# Processing 473/1000 → RVE_8x8_f0.40_0473.med
# Processing 474/1000 → RVE_8x8_f0.40_0474.med
# Processing 475/1000 → RVE_8x8_f0.40_0475.med
# Processing 476/1000 → RVE_8x8_f0.40_0476.med
# Processing 477/1000 → RVE_8x8_f0.40_0477.med
# Processing 478/1000 → RVE_8x8_f0.40_0478.med
# Processing 479/1000 → RVE_8x8_f0.40_0479.med
# Processing 480/1000 → RVE_8x8_f0.40_0480.med
# Processing 481/1000 → RVE_8x8_f0.40_0481.med
# Processing 482/1000 → RVE_8x8_f0.40_0482.med
# Processing 483/1000 → RVE_8x8_f0.40_0483.med
# Processing 484/1000 → RVE_8x8_f0.40_0484.med
# Processing 485/1000 → RVE_8x8_f0.40_0485.med
# Processing 486/1000 → RVE_8x8_f0.40_0486.med
# Processing 487/1000 → RVE_8x8_f0.40_0487.med
# Processing 488/1000 → RVE_8x8_f0.40_0488.med
# Processing 489/1000 → RVE_8x8_f0.40_0489.med
# Processing 490/1000 → RVE_8x8_f0.40_0490.med
# Processing 491/1000 → RVE_8x8_f0.40_0491.med
# Processing 492/1000 → RVE_8x8_f0.40_0492.med
# Processing 493/1000 → RVE_8x8_f0.40_0493.med
# Processing 494/1000 → RVE_8x8_f0.40_0494.med
# Processing 495/1000 → RVE_8x8_f0.40_0495.med
# Processing 496/1000 → RVE_8x8_f0.40_0496.med
# Processing 497/1000 → RVE_8x8_f0.40_0497.med
# Processing 498/1000 → RVE_8x8_f0.40_0498.med
# Processing 499/1000 → RVE_8x8_f0.40_0499.med
# Processing 500/1000 → RVE_8x8_f0.40_0500.med
# Processing 501/1000 → RVE_8x8_f0.40_0501.med
# Processing 502/1000 → RVE_8x8_f0.40_0502.med
# Processing 503/1000 → RVE_8x8_f0.40_0503.med
# Processing 504/1000 → RVE_8x8_f0.40_0504.med
# Processing 505/1000 → RVE_8x8_f0.40_0505.med
# Processing 506/1000 → RVE_8x8_f0.40_0506.med
# Processing 507/1000 → RVE_8x8_f0.40_0507.med
# Processing 508/1000 → RVE_8x8_f0.40_0508.med
# Processing 509/1000 → RVE_8x8_f0.40_0509.med
# Processing 510/1000 → RVE_8x8_f0.40_0510.med
# Processing 511/1000 → RVE_8x8_f0.40_0511.med
# Processing 512/1000 → RVE_8x8_f0.40_0512.med
# Processing 513/1000 → RVE_8x8_f0.40_0513.med
# Processing 514/1000 → RVE_8x8_f0.40_0514.med
# Processing 515/1000 → RVE_8x8_f0.40_0515.med
# Processing 516/1000 → RVE_8x8_f0.40_0516.med
# Processing 517/1000 → RVE_8x8_f0.40_0517.med
# Processing 518/1000 → RVE_8x8_f0.40_0518.med
# Processing 519/1000 → RVE_8x8_f0.40_0519.med
# Processing 520/1000 → RVE_8x8_f0.40_0520.med
# Processing 521/1000 → RVE_8x8_f0.40_0521.med
# Processing 522/1000 → RVE_8x8_f0.40_0522.med
# Processing 523/1000 → RVE_8x8_f0.40_0523.med
# Processing 524/1000 → RVE_8x8_f0.40_0524.med
# Processing 525/1000 → RVE_8x8_f0.40_0525.med
# Processing 526/1000 → RVE_8x8_f0.40_0526.med
# Processing 527/1000 → RVE_8x8_f0.40_0527.med
# Processing 528/1000 → RVE_8x8_f0.40_0528.med
# Processing 529/1000 → RVE_8x8_f0.40_0529.med
# Processing 530/1000 → RVE_8x8_f0.40_0530.med
# Processing 531/1000 → RVE_8x8_f0.40_0531.med
# Processing 532/1000 → RVE_8x8_f0.40_0532.med
# Processing 533/1000 → RVE_8x8_f0.40_0533.med
# Processing 534/1000 → RVE_8x8_f0.40_0534.med
# Processing 535/1000 → RVE_8x8_f0.40_0535.med
# Processing 536/1000 → RVE_8x8_f0.40_0536.med
# Processing 537/1000 → RVE_8x8_f0.40_0537.med
# Processing 538/1000 → RVE_8x8_f0.40_0538.med
# Processing 539/1000 → RVE_8x8_f0.40_0539.med
# Processing 540/1000 → RVE_8x8_f0.40_0540.med
# Processing 541/1000 → RVE_8x8_f0.40_0541.med
# Processing 542/1000 → RVE_8x8_f0.40_0542.med
# Processing 543/1000 → RVE_8x8_f0.40_0543.med
# Processing 544/1000 → RVE_8x8_f0.40_0544.med
# Processing 545/1000 → RVE_8x8_f0.40_0545.med
# Processing 546/1000 → RVE_8x8_f0.40_0546.med
# Processing 547/1000 → RVE_8x8_f0.40_0547.med
# Processing 548/1000 → RVE_8x8_f0.40_0548.med
# Processing 549/1000 → RVE_8x8_f0.40_0549.med
# Processing 550/1000 → RVE_8x8_f0.40_0550.med
# Processing 551/1000 → RVE_8x8_f0.40_0551.med
# Processing 552/1000 → RVE_8x8_f0.40_0552.med
# Processing 553/1000 → RVE_8x8_f0.40_0553.med
# Processing 554/1000 → RVE_8x8_f0.40_0554.med
# Processing 555/1000 → RVE_8x8_f0.40_0555.med
# Processing 556/1000 → RVE_8x8_f0.40_0556.med
# Processing 557/1000 → RVE_8x8_f0.40_0557.med
# Processing 558/1000 → RVE_8x8_f0.40_0558.med
# Processing 559/1000 → RVE_8x8_f0.40_0559.med
# Processing 560/1000 → RVE_8x8_f0.40_0560.med
# Processing 561/1000 → RVE_8x8_f0.40_0561.med
# Processing 562/1000 → RVE_8x8_f0.40_0562.med
# Processing 563/1000 → RVE_8x8_f0.40_0563.med
# Processing 564/1000 → RVE_8x8_f0.40_0564.med
# Processing 565/1000 → RVE_8x8_f0.40_0565.med
# Processing 566/1000 → RVE_8x8_f0.40_0566.med
# Processing 567/1000 → RVE_8x8_f0.40_0567.med
# Processing 568/1000 → RVE_8x8_f0.40_0568.med
# Processing 569/1000 → RVE_8x8_f0.40_0569.med
# Processing 570/1000 → RVE_8x8_f0.40_0570.med
# Processing 571/1000 → RVE_8x8_f0.40_0571.med
# Processing 572/1000 → RVE_8x8_f0.40_0572.med
# Processing 573/1000 → RVE_8x8_f0.40_0573.med
# Processing 574/1000 → RVE_8x8_f0.40_0574.med
# Processing 575/1000 → RVE_8x8_f0.40_0575.med
# Processing 576/1000 → RVE_8x8_f0.40_0576.med
# Processing 577/1000 → RVE_8x8_f0.40_0577.med
# Processing 578/1000 → RVE_8x8_f0.40_0578.med
# Processing 579/1000 → RVE_8x8_f0.40_0579.med
# Processing 580/1000 → RVE_8x8_f0.40_0580.med
# Processing 581/1000 → RVE_8x8_f0.40_0581.med
# Processing 582/1000 → RVE_8x8_f0.40_0582.med
# Processing 583/1000 → RVE_8x8_f0.40_0583.med
# Processing 584/1000 → RVE_8x8_f0.40_0584.med
# Processing 585/1000 → RVE_8x8_f0.40_0585.med
# Processing 586/1000 → RVE_8x8_f0.40_0586.med
# Processing 587/1000 → RVE_8x8_f0.40_0587.med
# Processing 588/1000 → RVE_8x8_f0.40_0588.med
# Processing 589/1000 → RVE_8x8_f0.40_0589.med
# Processing 590/1000 → RVE_8x8_f0.40_0590.med
# Processing 591/1000 → RVE_8x8_f0.40_0591.med
# Processing 592/1000 → RVE_8x8_f0.40_0592.med
# Processing 593/1000 → RVE_8x8_f0.40_0593.med
# Processing 594/1000 → RVE_8x8_f0.40_0594.med
# Processing 595/1000 → RVE_8x8_f0.40_0595.med
# Processing 596/1000 → RVE_8x8_f0.40_0596.med
# Processing 597/1000 → RVE_8x8_f0.40_0597.med
# Processing 598/1000 → RVE_8x8_f0.40_0598.med
# Processing 599/1000 → RVE_8x8_f0.40_0599.med
# Processing 600/1000 → RVE_8x8_f0.40_0600.med
# Processing 601/1000 → RVE_8x8_f0.40_0601.med
# Processing 602/1000 → RVE_8x8_f0.40_0602.med
# Processing 603/1000 → RVE_8x8_f0.40_0603.med
# Processing 604/1000 → RVE_8x8_f0.40_0604.med
# Processing 605/1000 → RVE_8x8_f0.40_0605.med
# Processing 606/1000 → RVE_8x8_f0.40_0606.med
# Processing 607/1000 → RVE_8x8_f0.40_0607.med
# Processing 608/1000 → RVE_8x8_f0.40_0608.med
# Processing 609/1000 → RVE_8x8_f0.40_0609.med
# Processing 610/1000 → RVE_8x8_f0.40_0610.med
# Processing 611/1000 → RVE_8x8_f0.40_0611.med
# Processing 612/1000 → RVE_8x8_f0.40_0612.med
# Processing 613/1000 → RVE_8x8_f0.40_0613.med
# Processing 614/1000 → RVE_8x8_f0.40_0614.med
# Processing 615/1000 → RVE_8x8_f0.40_0615.med
# Processing 616/1000 → RVE_8x8_f0.40_0616.med
# Processing 617/1000 → RVE_8x8_f0.40_0617.med
# Processing 618/1000 → RVE_8x8_f0.40_0618.med
# Processing 619/1000 → RVE_8x8_f0.40_0619.med
# Processing 620/1000 → RVE_8x8_f0.40_0620.med
# Processing 621/1000 → RVE_8x8_f0.40_0621.med
# Processing 622/1000 → RVE_8x8_f0.40_0622.med
# Processing 623/1000 → RVE_8x8_f0.40_0623.med
# Processing 624/1000 → RVE_8x8_f0.40_0624.med
# Processing 625/1000 → RVE_8x8_f0.40_0625.med
# Processing 626/1000 → RVE_8x8_f0.40_0626.med
# Processing 627/1000 → RVE_8x8_f0.40_0627.med
# Processing 628/1000 → RVE_8x8_f0.40_0628.med
# Processing 629/1000 → RVE_8x8_f0.40_0629.med
# Processing 630/1000 → RVE_8x8_f0.40_0630.med
# Processing 631/1000 → RVE_8x8_f0.40_0631.med
# Processing 632/1000 → RVE_8x8_f0.40_0632.med
# Processing 633/1000 → RVE_8x8_f0.40_0633.med
# Processing 634/1000 → RVE_8x8_f0.40_0634.med
# Processing 635/1000 → RVE_8x8_f0.40_0635.med
# Processing 636/1000 → RVE_8x8_f0.40_0636.med
# Processing 637/1000 → RVE_8x8_f0.40_0637.med
# Processing 638/1000 → RVE_8x8_f0.40_0638.med
# Processing 639/1000 → RVE_8x8_f0.40_0639.med
# Processing 640/1000 → RVE_8x8_f0.40_0640.med
# Processing 641/1000 → RVE_8x8_f0.40_0641.med
# Processing 642/1000 → RVE_8x8_f0.40_0642.med
# Processing 643/1000 → RVE_8x8_f0.40_0643.med
# Processing 644/1000 → RVE_8x8_f0.40_0644.med
# Processing 645/1000 → RVE_8x8_f0.40_0645.med
# Processing 646/1000 → RVE_8x8_f0.40_0646.med
# Processing 647/1000 → RVE_8x8_f0.40_0647.med
# Processing 648/1000 → RVE_8x8_f0.40_0648.med
# Processing 649/1000 → RVE_8x8_f0.40_0649.med
# Processing 650/1000 → RVE_8x8_f0.40_0650.med
# Processing 651/1000 → RVE_8x8_f0.40_0651.med
# Processing 652/1000 → RVE_8x8_f0.40_0652.med
# Processing 653/1000 → RVE_8x8_f0.40_0653.med
# Processing 654/1000 → RVE_8x8_f0.40_0654.med
# Processing 655/1000 → RVE_8x8_f0.40_0655.med
# Processing 656/1000 → RVE_8x8_f0.40_0656.med
# Processing 657/1000 → RVE_8x8_f0.40_0657.med
# Processing 658/1000 → RVE_8x8_f0.40_0658.med
# Processing 659/1000 → RVE_8x8_f0.40_0659.med
# Processing 660/1000 → RVE_8x8_f0.40_0660.med
# Processing 661/1000 → RVE_8x8_f0.40_0661.med
# Processing 662/1000 → RVE_8x8_f0.40_0662.med
# Processing 663/1000 → RVE_8x8_f0.40_0663.med
# Processing 664/1000 → RVE_8x8_f0.40_0664.med
# Processing 665/1000 → RVE_8x8_f0.40_0665.med
# Processing 666/1000 → RVE_8x8_f0.40_0666.med
# Processing 667/1000 → RVE_8x8_f0.40_0667.med
# Processing 668/1000 → RVE_8x8_f0.40_0668.med
# Processing 669/1000 → RVE_8x8_f0.40_0669.med
# Processing 670/1000 → RVE_8x8_f0.40_0670.med
# Processing 671/1000 → RVE_8x8_f0.40_0671.med
# Processing 672/1000 → RVE_8x8_f0.40_0672.med
# Processing 673/1000 → RVE_8x8_f0.40_0673.med
# Processing 674/1000 → RVE_8x8_f0.40_0674.med
# Processing 675/1000 → RVE_8x8_f0.40_0675.med
# Processing 676/1000 → RVE_8x8_f0.40_0676.med
# Processing 677/1000 → RVE_8x8_f0.40_0677.med
# Processing 678/1000 → RVE_8x8_f0.40_0678.med
# Processing 679/1000 → RVE_8x8_f0.40_0679.med
# Processing 680/1000 → RVE_8x8_f0.40_0680.med
# Processing 681/1000 → RVE_8x8_f0.40_0681.med
# Processing 682/1000 → RVE_8x8_f0.40_0682.med
# Processing 683/1000 → RVE_8x8_f0.40_0683.med
# Processing 684/1000 → RVE_8x8_f0.40_0684.med
# Processing 685/1000 → RVE_8x8_f0.40_0685.med
# Processing 686/1000 → RVE_8x8_f0.40_0686.med
# Processing 687/1000 → RVE_8x8_f0.40_0687.med
# Processing 688/1000 → RVE_8x8_f0.40_0688.med
# Processing 689/1000 → RVE_8x8_f0.40_0689.med
# Processing 690/1000 → RVE_8x8_f0.40_0690.med
# Processing 691/1000 → RVE_8x8_f0.40_0691.med
# Processing 692/1000 → RVE_8x8_f0.40_0692.med
# Processing 693/1000 → RVE_8x8_f0.40_0693.med
# Processing 694/1000 → RVE_8x8_f0.40_0694.med
# Processing 695/1000 → RVE_8x8_f0.40_0695.med
# Processing 696/1000 → RVE_8x8_f0.40_0696.med
# Processing 697/1000 → RVE_8x8_f0.40_0697.med
# Processing 698/1000 → RVE_8x8_f0.40_0698.med
# Processing 699/1000 → RVE_8x8_f0.40_0699.med
# Processing 700/1000 → RVE_8x8_f0.40_0700.med
# Processing 701/1000 → RVE_8x8_f0.40_0701.med
# Processing 702/1000 → RVE_8x8_f0.40_0702.med
# Processing 703/1000 → RVE_8x8_f0.40_0703.med
# Processing 704/1000 → RVE_8x8_f0.40_0704.med
# Processing 705/1000 → RVE_8x8_f0.40_0705.med
# Processing 706/1000 → RVE_8x8_f0.40_0706.med
# Processing 707/1000 → RVE_8x8_f0.40_0707.med
# Processing 708/1000 → RVE_8x8_f0.40_0708.med
# Processing 709/1000 → RVE_8x8_f0.40_0709.med
# Processing 710/1000 → RVE_8x8_f0.40_0710.med
# Processing 711/1000 → RVE_8x8_f0.40_0711.med
# Processing 712/1000 → RVE_8x8_f0.40_0712.med
# Processing 713/1000 → RVE_8x8_f0.40_0713.med
# Processing 714/1000 → RVE_8x8_f0.40_0714.med
# Processing 715/1000 → RVE_8x8_f0.40_0715.med
# Processing 716/1000 → RVE_8x8_f0.40_0716.med
# Processing 717/1000 → RVE_8x8_f0.40_0717.med
# Processing 718/1000 → RVE_8x8_f0.40_0718.med
# Processing 719/1000 → RVE_8x8_f0.40_0719.med
# Processing 720/1000 → RVE_8x8_f0.40_0720.med
# Processing 721/1000 → RVE_8x8_f0.40_0721.med
# Processing 722/1000 → RVE_8x8_f0.40_0722.med
# Processing 723/1000 → RVE_8x8_f0.40_0723.med
# Processing 724/1000 → RVE_8x8_f0.40_0724.med
# Processing 725/1000 → RVE_8x8_f0.40_0725.med
# Processing 726/1000 → RVE_8x8_f0.40_0726.med
# Processing 727/1000 → RVE_8x8_f0.40_0727.med
# Processing 728/1000 → RVE_8x8_f0.40_0728.med
# Processing 729/1000 → RVE_8x8_f0.40_0729.med
# Processing 730/1000 → RVE_8x8_f0.40_0730.med
# Processing 731/1000 → RVE_8x8_f0.40_0731.med
# Processing 732/1000 → RVE_8x8_f0.40_0732.med
# Processing 733/1000 → RVE_8x8_f0.40_0733.med
# Processing 734/1000 → RVE_8x8_f0.40_0734.med
# Processing 735/1000 → RVE_8x8_f0.40_0735.med
# Processing 736/1000 → RVE_8x8_f0.40_0736.med
# Processing 737/1000 → RVE_8x8_f0.40_0737.med
# Processing 738/1000 → RVE_8x8_f0.40_0738.med
# Processing 739/1000 → RVE_8x8_f0.40_0739.med
# Processing 740/1000 → RVE_8x8_f0.40_0740.med
# Processing 741/1000 → RVE_8x8_f0.40_0741.med
# Processing 742/1000 → RVE_8x8_f0.40_0742.med
# Processing 743/1000 → RVE_8x8_f0.40_0743.med
# Processing 744/1000 → RVE_8x8_f0.40_0744.med
# Processing 745/1000 → RVE_8x8_f0.40_0745.med
# Processing 746/1000 → RVE_8x8_f0.40_0746.med
# Processing 747/1000 → RVE_8x8_f0.40_0747.med
# Processing 748/1000 → RVE_8x8_f0.40_0748.med
# Processing 749/1000 → RVE_8x8_f0.40_0749.med
# Processing 750/1000 → RVE_8x8_f0.40_0750.med
# Processing 751/1000 → RVE_8x8_f0.40_0751.med
# Processing 752/1000 → RVE_8x8_f0.40_0752.med
# Processing 753/1000 → RVE_8x8_f0.40_0753.med
# Processing 754/1000 → RVE_8x8_f0.40_0754.med
# Processing 755/1000 → RVE_8x8_f0.40_0755.med
# Processing 756/1000 → RVE_8x8_f0.40_0756.med
# Processing 757/1000 → RVE_8x8_f0.40_0757.med
# Processing 758/1000 → RVE_8x8_f0.40_0758.med
# Processing 759/1000 → RVE_8x8_f0.40_0759.med
# Processing 760/1000 → RVE_8x8_f0.40_0760.med
# Processing 761/1000 → RVE_8x8_f0.40_0761.med
# Processing 762/1000 → RVE_8x8_f0.40_0762.med
# Processing 763/1000 → RVE_8x8_f0.40_0763.med
# Processing 764/1000 → RVE_8x8_f0.40_0764.med
# Processing 765/1000 → RVE_8x8_f0.40_0765.med
# Processing 766/1000 → RVE_8x8_f0.40_0766.med
# Processing 767/1000 → RVE_8x8_f0.40_0767.med
# Processing 768/1000 → RVE_8x8_f0.40_0768.med
# Processing 769/1000 → RVE_8x8_f0.40_0769.med
# Processing 770/1000 → RVE_8x8_f0.40_0770.med
# Processing 771/1000 → RVE_8x8_f0.40_0771.med
# Processing 772/1000 → RVE_8x8_f0.40_0772.med
# Processing 773/1000 → RVE_8x8_f0.40_0773.med
# Processing 774/1000 → RVE_8x8_f0.40_0774.med
# Processing 775/1000 → RVE_8x8_f0.40_0775.med
# Processing 776/1000 → RVE_8x8_f0.40_0776.med
# Processing 777/1000 → RVE_8x8_f0.40_0777.med
# Processing 778/1000 → RVE_8x8_f0.40_0778.med
# Processing 779/1000 → RVE_8x8_f0.40_0779.med
# Processing 780/1000 → RVE_8x8_f0.40_0780.med
# Processing 781/1000 → RVE_8x8_f0.40_0781.med
# Processing 782/1000 → RVE_8x8_f0.40_0782.med
# Processing 783/1000 → RVE_8x8_f0.40_0783.med
# Processing 784/1000 → RVE_8x8_f0.40_0784.med
# Processing 785/1000 → RVE_8x8_f0.40_0785.med
# Processing 786/1000 → RVE_8x8_f0.40_0786.med
# Processing 787/1000 → RVE_8x8_f0.40_0787.med
# Processing 788/1000 → RVE_8x8_f0.40_0788.med
# Processing 789/1000 → RVE_8x8_f0.40_0789.med
# Processing 790/1000 → RVE_8x8_f0.40_0790.med
# Processing 791/1000 → RVE_8x8_f0.40_0791.med
# Processing 792/1000 → RVE_8x8_f0.40_0792.med
# Processing 793/1000 → RVE_8x8_f0.40_0793.med
# Processing 794/1000 → RVE_8x8_f0.40_0794.med
# Processing 795/1000 → RVE_8x8_f0.40_0795.med
# Processing 796/1000 → RVE_8x8_f0.40_0796.med
# Processing 797/1000 → RVE_8x8_f0.40_0797.med
# Processing 798/1000 → RVE_8x8_f0.40_0798.med
# Processing 799/1000 → RVE_8x8_f0.40_0799.med
# Processing 800/1000 → RVE_8x8_f0.40_0800.med
# Processing 801/1000 → RVE_8x8_f0.40_0801.med
# Processing 802/1000 → RVE_8x8_f0.40_0802.med
# Processing 803/1000 → RVE_8x8_f0.40_0803.med
# Processing 804/1000 → RVE_8x8_f0.40_0804.med
# Processing 805/1000 → RVE_8x8_f0.40_0805.med
# Processing 806/1000 → RVE_8x8_f0.40_0806.med
# Processing 807/1000 → RVE_8x8_f0.40_0807.med
# Processing 808/1000 → RVE_8x8_f0.40_0808.med
# Processing 809/1000 → RVE_8x8_f0.40_0809.med
# Processing 810/1000 → RVE_8x8_f0.40_0810.med
# Processing 811/1000 → RVE_8x8_f0.40_0811.med
# Processing 812/1000 → RVE_8x8_f0.40_0812.med
# Processing 813/1000 → RVE_8x8_f0.40_0813.med
# Processing 814/1000 → RVE_8x8_f0.40_0814.med
# Processing 815/1000 → RVE_8x8_f0.40_0815.med
# Processing 816/1000 → RVE_8x8_f0.40_0816.med
# Processing 817/1000 → RVE_8x8_f0.40_0817.med
# Processing 818/1000 → RVE_8x8_f0.40_0818.med
# Processing 819/1000 → RVE_8x8_f0.40_0819.med
# Processing 820/1000 → RVE_8x8_f0.40_0820.med
# Processing 821/1000 → RVE_8x8_f0.40_0821.med
# Processing 822/1000 → RVE_8x8_f0.40_0822.med
# Processing 823/1000 → RVE_8x8_f0.40_0823.med
# Processing 824/1000 → RVE_8x8_f0.40_0824.med
# Processing 825/1000 → RVE_8x8_f0.40_0825.med
# Processing 826/1000 → RVE_8x8_f0.40_0826.med
# Processing 827/1000 → RVE_8x8_f0.40_0827.med
# Processing 828/1000 → RVE_8x8_f0.40_0828.med
# Processing 829/1000 → RVE_8x8_f0.40_0829.med
# Processing 830/1000 → RVE_8x8_f0.40_0830.med
# Processing 831/1000 → RVE_8x8_f0.40_0831.med
# Processing 832/1000 → RVE_8x8_f0.40_0832.med
# Processing 833/1000 → RVE_8x8_f0.40_0833.med
# Processing 834/1000 → RVE_8x8_f0.40_0834.med
# Processing 835/1000 → RVE_8x8_f0.40_0835.med
# Processing 836/1000 → RVE_8x8_f0.40_0836.med
# Processing 837/1000 → RVE_8x8_f0.40_0837.med
# Processing 838/1000 → RVE_8x8_f0.40_0838.med
# Processing 839/1000 → RVE_8x8_f0.40_0839.med
# Processing 840/1000 → RVE_8x8_f0.40_0840.med
# Processing 841/1000 → RVE_8x8_f0.40_0841.med
# Processing 842/1000 → RVE_8x8_f0.40_0842.med
# Processing 843/1000 → RVE_8x8_f0.40_0843.med
# Processing 844/1000 → RVE_8x8_f0.40_0844.med
# Processing 845/1000 → RVE_8x8_f0.40_0845.med
# Processing 846/1000 → RVE_8x8_f0.40_0846.med
# Processing 847/1000 → RVE_8x8_f0.40_0847.med
# Processing 848/1000 → RVE_8x8_f0.40_0848.med
# Processing 849/1000 → RVE_8x8_f0.40_0849.med
# Processing 850/1000 → RVE_8x8_f0.40_0850.med
# Processing 851/1000 → RVE_8x8_f0.40_0851.med
# Processing 852/1000 → RVE_8x8_f0.40_0852.med
# Processing 853/1000 → RVE_8x8_f0.40_0853.med
# Processing 854/1000 → RVE_8x8_f0.40_0854.med
# Processing 855/1000 → RVE_8x8_f0.40_0855.med
# Processing 856/1000 → RVE_8x8_f0.40_0856.med
# Processing 857/1000 → RVE_8x8_f0.40_0857.med
# Processing 858/1000 → RVE_8x8_f0.40_0858.med
# Processing 859/1000 → RVE_8x8_f0.40_0859.med
# Processing 860/1000 → RVE_8x8_f0.40_0860.med
# Processing 861/1000 → RVE_8x8_f0.40_0861.med
# Processing 862/1000 → RVE_8x8_f0.40_0862.med
# Processing 863/1000 → RVE_8x8_f0.40_0863.med
# Processing 864/1000 → RVE_8x8_f0.40_0864.med
# Processing 865/1000 → RVE_8x8_f0.40_0865.med
# Processing 866/1000 → RVE_8x8_f0.40_0866.med
# Processing 867/1000 → RVE_8x8_f0.40_0867.med
# Processing 868/1000 → RVE_8x8_f0.40_0868.med
# Processing 869/1000 → RVE_8x8_f0.40_0869.med
# Processing 870/1000 → RVE_8x8_f0.40_0870.med
# Processing 871/1000 → RVE_8x8_f0.40_0871.med
# Processing 872/1000 → RVE_8x8_f0.40_0872.med
# Processing 873/1000 → RVE_8x8_f0.40_0873.med
# Processing 874/1000 → RVE_8x8_f0.40_0874.med
# Processing 875/1000 → RVE_8x8_f0.40_0875.med
# Processing 876/1000 → RVE_8x8_f0.40_0876.med
# Processing 877/1000 → RVE_8x8_f0.40_0877.med
# Processing 878/1000 → RVE_8x8_f0.40_0878.med
# Processing 879/1000 → RVE_8x8_f0.40_0879.med
# Processing 880/1000 → RVE_8x8_f0.40_0880.med
# Processing 881/1000 → RVE_8x8_f0.40_0881.med
# Processing 882/1000 → RVE_8x8_f0.40_0882.med
# Processing 883/1000 → RVE_8x8_f0.40_0883.med
# Processing 884/1000 → RVE_8x8_f0.40_0884.med
# Processing 885/1000 → RVE_8x8_f0.40_0885.med
# Processing 886/1000 → RVE_8x8_f0.40_0886.med
# Processing 887/1000 → RVE_8x8_f0.40_0887.med
# Processing 888/1000 → RVE_8x8_f0.40_0888.med
# Processing 889/1000 → RVE_8x8_f0.40_0889.med
# Processing 890/1000 → RVE_8x8_f0.40_0890.med
# Processing 891/1000 → RVE_8x8_f0.40_0891.med
# Processing 892/1000 → RVE_8x8_f0.40_0892.med
# Processing 893/1000 → RVE_8x8_f0.40_0893.med
# Processing 894/1000 → RVE_8x8_f0.40_0894.med
# Processing 895/1000 → RVE_8x8_f0.40_0895.med
# Processing 896/1000 → RVE_8x8_f0.40_0896.med
# Processing 897/1000 → RVE_8x8_f0.40_0897.med
# Processing 898/1000 → RVE_8x8_f0.40_0898.med
# Processing 899/1000 → RVE_8x8_f0.40_0899.med
# Processing 900/1000 → RVE_8x8_f0.40_0900.med
# Processing 901/1000 → RVE_8x8_f0.40_0901.med
# Processing 902/1000 → RVE_8x8_f0.40_0902.med
# Processing 903/1000 → RVE_8x8_f0.40_0903.med
# Processing 904/1000 → RVE_8x8_f0.40_0904.med
# Processing 905/1000 → RVE_8x8_f0.40_0905.med
# Processing 906/1000 → RVE_8x8_f0.40_0906.med
# Processing 907/1000 → RVE_8x8_f0.40_0907.med
# Processing 908/1000 → RVE_8x8_f0.40_0908.med
# Processing 909/1000 → RVE_8x8_f0.40_0909.med
# Processing 910/1000 → RVE_8x8_f0.40_0910.med
# Processing 911/1000 → RVE_8x8_f0.40_0911.med
# Processing 912/1000 → RVE_8x8_f0.40_0912.med
# Processing 913/1000 → RVE_8x8_f0.40_0913.med
# Processing 914/1000 → RVE_8x8_f0.40_0914.med
# Processing 915/1000 → RVE_8x8_f0.40_0915.med
# Processing 916/1000 → RVE_8x8_f0.40_0916.med
# Processing 917/1000 → RVE_8x8_f0.40_0917.med
# Processing 918/1000 → RVE_8x8_f0.40_0918.med
# Processing 919/1000 → RVE_8x8_f0.40_0919.med
# Processing 920/1000 → RVE_8x8_f0.40_0920.med
# Processing 921/1000 → RVE_8x8_f0.40_0921.med
# Processing 922/1000 → RVE_8x8_f0.40_0922.med
# Processing 923/1000 → RVE_8x8_f0.40_0923.med
# Processing 924/1000 → RVE_8x8_f0.40_0924.med
# Processing 925/1000 → RVE_8x8_f0.40_0925.med
# Processing 926/1000 → RVE_8x8_f0.40_0926.med
# Processing 927/1000 → RVE_8x8_f0.40_0927.med
# Processing 928/1000 → RVE_8x8_f0.40_0928.med
# Processing 929/1000 → RVE_8x8_f0.40_0929.med
# Processing 930/1000 → RVE_8x8_f0.40_0930.med
# Processing 931/1000 → RVE_8x8_f0.40_0931.med
# Processing 932/1000 → RVE_8x8_f0.40_0932.med
# Processing 933/1000 → RVE_8x8_f0.40_0933.med
# Processing 934/1000 → RVE_8x8_f0.40_0934.med
# Processing 935/1000 → RVE_8x8_f0.40_0935.med
# Processing 936/1000 → RVE_8x8_f0.40_0936.med
# Processing 937/1000 → RVE_8x8_f0.40_0937.med
# Processing 938/1000 → RVE_8x8_f0.40_0938.med
# Processing 939/1000 → RVE_8x8_f0.40_0939.med
# Processing 940/1000 → RVE_8x8_f0.40_0940.med
# Processing 941/1000 → RVE_8x8_f0.40_0941.med
# Processing 942/1000 → RVE_8x8_f0.40_0942.med
# Processing 943/1000 → RVE_8x8_f0.40_0943.med
# Processing 944/1000 → RVE_8x8_f0.40_0944.med
# Processing 945/1000 → RVE_8x8_f0.40_0945.med
# Processing 946/1000 → RVE_8x8_f0.40_0946.med
# Processing 947/1000 → RVE_8x8_f0.40_0947.med
# Processing 948/1000 → RVE_8x8_f0.40_0948.med
# Processing 949/1000 → RVE_8x8_f0.40_0949.med
# Processing 950/1000 → RVE_8x8_f0.40_0950.med
# Processing 951/1000 → RVE_8x8_f0.40_0951.med
# Processing 952/1000 → RVE_8x8_f0.40_0952.med
# Processing 953/1000 → RVE_8x8_f0.40_0953.med
# Processing 954/1000 → RVE_8x8_f0.40_0954.med
# Processing 955/1000 → RVE_8x8_f0.40_0955.med
# Processing 956/1000 → RVE_8x8_f0.40_0956.med
# Processing 957/1000 → RVE_8x8_f0.40_0957.med
# Processing 958/1000 → RVE_8x8_f0.40_0958.med
# Processing 959/1000 → RVE_8x8_f0.40_0959.med
# Processing 960/1000 → RVE_8x8_f0.40_0960.med
# Processing 961/1000 → RVE_8x8_f0.40_0961.med
# Processing 962/1000 → RVE_8x8_f0.40_0962.med
# Processing 963/1000 → RVE_8x8_f0.40_0963.med
# Processing 964/1000 → RVE_8x8_f0.40_0964.med
# Processing 965/1000 → RVE_8x8_f0.40_0965.med
# Processing 966/1000 → RVE_8x8_f0.40_0966.med
# Processing 967/1000 → RVE_8x8_f0.40_0967.med
# Processing 968/1000 → RVE_8x8_f0.40_0968.med
# Processing 969/1000 → RVE_8x8_f0.40_0969.med
# Processing 970/1000 → RVE_8x8_f0.40_0970.med
# Processing 971/1000 → RVE_8x8_f0.40_0971.med
# Processing 972/1000 → RVE_8x8_f0.40_0972.med
# Processing 973/1000 → RVE_8x8_f0.40_0973.med
# Processing 974/1000 → RVE_8x8_f0.40_0974.med
# Processing 975/1000 → RVE_8x8_f0.40_0975.med
# Processing 976/1000 → RVE_8x8_f0.40_0976.med
# Processing 977/1000 → RVE_8x8_f0.40_0977.med
# Processing 978/1000 → RVE_8x8_f0.40_0978.med
# Processing 979/1000 → RVE_8x8_f0.40_0979.med
# Processing 980/1000 → RVE_8x8_f0.40_0980.med
# Processing 981/1000 → RVE_8x8_f0.40_0981.med
# Processing 982/1000 → RVE_8x8_f0.40_0982.med
# Processing 983/1000 → RVE_8x8_f0.40_0983.med
# Processing 984/1000 → RVE_8x8_f0.40_0984.med
# Processing 985/1000 → RVE_8x8_f0.40_0985.med
# Processing 986/1000 → RVE_8x8_f0.40_0986.med
# Processing 987/1000 → RVE_8x8_f0.40_0987.med
# Processing 988/1000 → RVE_8x8_f0.40_0988.med
# Processing 989/1000 → RVE_8x8_f0.40_0989.med
# Processing 990/1000 → RVE_8x8_f0.40_0990.med
# Processing 991/1000 → RVE_8x8_f0.40_0991.med
# Processing 992/1000 → RVE_8x8_f0.40_0992.med
# Processing 993/1000 → RVE_8x8_f0.40_0993.med
# Processing 994/1000 → RVE_8x8_f0.40_0994.med
# Processing 995/1000 → RVE_8x8_f0.40_0995.med
# Processing 996/1000 → RVE_8x8_f0.40_0996.med
# Processing 997/1000 → RVE_8x8_f0.40_0997.med
# Processing 998/1000 → RVE_8x8_f0.40_0998.med
# Processing 999/1000 → RVE_8x8_f0.40_0999.med
# Processing 1000/1000 → RVE_8x8_f0.40_1000.med
#
#  Process finished. Files saved at:
# data\Run1

# %%
# ==================== CHECK FILE ====================

def check_rve_data(rve_file):
    with h5py.File(rve_file, 'r') as f:
        print("✅ File opened successfully")
        print("Available keys        :", list(f.keys()))
        print("File attributes       :")
        for key, val in f.attrs.items():
            print(f"   {key:15} = {val}")
        
        # Datasets
        fields = f['fields'][:]      # (N_steps, H, W, nchannels)
        macro  = f['macro'][:]       # (N_steps, nmacro)
        
        print("\n📊 Shapes:")
        print(f"   fields → {fields.shape}  → [phase(0=soft,1=hard), Sxx, Syy, Sxy]")
        print(f"   macro  → {macro.shape}   → [exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard]")
        
        H, W = fields.shape[1], fields.shape[2]
        print(f"\n🔍 Grid check: {H}×{W} → {'✅ OK' if H == W else '❌ Not square'}")
        
        # Check phases
        phase_unique = np.unique(fields[0, :, :, 0])
        print(f"   Unique phases: {phase_unique} → {'✅ Correct' if len(phase_unique)==2 else '❌'}")
        
        # First macro values
        print(f"   First macro: exx={macro[0,0]:.6f}, "
              f"eyy={macro[0,1]:.6f}, "
              f"gxy={macro[0,2]:.6f}")

        return fields, macro

# Test
rve_file = "./data/Run1/rve_0001.h5"
fields, macro = check_rve_data(rve_file)
# Out:
# ✅ File opened successfully
# Available keys        : ['fields', 'macro']
# File attributes       :
#    H_gp            = 96
#    W_gp            = 96
#    description     = Dual-Encoder FNO: fields[phase(0=soft,1=hard), sXX, sYY, sXY] + macro[exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard]
#    mesh_name       = RVE_8x8_f0.40_0001.med
#    n_steps         = 100
#    ngp             = 2
#
# 📊 Shapes:
#    fields → (100, 96, 96, 4)  → [phase(0=soft,1=hard), Sxx, Syy, Sxy]
#    macro  → (100, 7)   → [exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard]
#
# 🔍 Grid check: 96×96 → ✅ OK
#    Unique phases: [0. 1.] → ✅ Correct
#    First macro: exx=0.000016, eyy=0.000014, gxy=0.000000

# %%
# ==================== PLOTS ====================

def plot_fields(fields, macro, step=-1):
    """
    Plot fields and macro strain for a given step.
    fields: (N_steps, H, W, 4) → [phase, Sxx, Syy, Sxy]
    macro:  (N_steps, 7)      → [exx, eyy, gxy, E_soft, nu_soft, E_hard, nu_hard]
    """
    fig, axs = plt.subplots(2, 2, figsize=(12, 10))
    
    titles = [
        "Material Phase\n(0 = soft, 1 = hard)",
        "SXX (MPa)",
        "SYY (MPa)",
        "SXY (MPa)"
    ]
    
    data = [
        fields[step-1, :, :, 0],   # phase
        fields[step-1, :, :, 1],   # σxx
        fields[step-1, :, :, 2],   # σyy
        fields[step-1, :, :, 3]    # σxy
    ]

    for i, ax in enumerate(axs.flat):
        im = ax.imshow(data[i], cmap='viridis', origin='lower')
        ax.set_title(titles[i])
        ax.set_xlabel('X Grid')
        ax.set_ylabel('Y Grid')
        plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)

    # Show only macro strain components in title
    eps = macro[step-1, :3]  # exx, eyy, gxy
    plt.suptitle(f'RVE 001 – Step {step} | '
                 f'Macro strain = [{eps[0]:.6f}, {eps[1]:.6f}, {eps[2]:.6f}]',
                 fontsize=14)
    
    plt.tight_layout()
    plt.show()


# Test
plot_fields(fields, macro, step=100)
